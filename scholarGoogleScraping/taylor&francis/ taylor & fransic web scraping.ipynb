# %%
from bs4 import BeautifulSoup
import requests
import pandas
titlesArray=[]
keywordsArray=[]
affilisArray=[]
abstractsArray=[]
publicationsArray=[]
linksArray=[]
publisherArray=[]

tags = requests.get('https://scholar.google.com/scholar?start=40&q=blockchain+iran+Taylor+%26+Francis+-BOOK&hl=en&as_sdt=0,5&as_ylo=2018').text
soup = BeautifulSoup(tags, 'html') 


                            
linksOfTitles=soup.select('#gs_res_ccl_mid > div > div.gs_ri > h3>a')
for link in linksOfTitles:
  linksArray.append(link['href'])
        
data={ 'links':linksArray}
d= pandas.DataFrame(data)
d[d.links.str.contains('link.springer.com')]
# print(d[d.links.str.contains('link.springer.com')])

for ind in d[d.links.str.contains('tandfonline.com')].index:
    link2=d[d.links.str.contains('tandfonline.com')]['links'][ind]
    print(link2)
    tags2 = requests.get(link2)
    soup2 = BeautifulSoup(tags2.text, 'html')
    abstracts=soup2.select(' div.hlFld-Abstract> div> p') 
       
      
    publisherArray.append('taylor&fransic')

    
    for abstract in abstracts:
     if abstract.text!='ABSTRACT'and abstract.text!='Abstract':
      abstractsArray.append(abstract.text)

    titles=soup2.select('#fa57727f-b942-4eb8-9ed2-ecfe11ac03f5 > div > div > h1 > span')
    for title in titles:
     titlesArray.append(title.text)

    affiliations=soup2.select('#fa57727f-b942-4eb8-9ed2-ecfe11ac03f5 > div > div > div.literatumAuthors > div > div > span')
    for affili in affiliations:
     affilisArray.append(affili)
        
    
data={ 'publisher':publisherArray,'abstracts':abstractsArray, 'titles':titlesArray,'affiliations':affilisArray, }
df= pandas.DataFrame(data)
print(df)
df.to_excel("C:/Users/musta/Desktop/scholar_scrape/excel/taylor4.xlsx")
# Out:
# https://www.tandfonline.com/doi/abs/10.1080/17509653.2022.2032442
# https://www.tandfonline.com/doi/abs/10.1080/15435075.2022.2038610
# https://www.tandfonline.com/doi/abs/10.1080/09537325.2022.2035349
# https://www.tandfonline.com/doi/abs/10.1080/00207543.2019.1681137
# https://www.tandfonline.com/doi/abs/10.1080/00207543.2020.1723813
# https://www.tandfonline.com/doi/abs/10.1080/00207543.2019.1574042
#         publisher                                          abstracts  \
# 0  taylor&fransic   Predicting the future price of the currency h...
# 1  taylor&fransic  The smart grid is not a monolithic system, but...
# 2  taylor&fransic  Technological upgradation is the driving force...
# 3  taylor&fransic  In recent years, topics such as sharing econom...
# 4  taylor&fransic  This paper analytically explores drug recall p...
# 5  taylor&fransic  Organisational and managerial decisions are in...
#
#                                               titles  \
# 0  Analysis of different artificial neural networ...
# 1  Smart grid mechanism for green energy manageme...
# 2  A digital analysis system of patents integrati...
# 3  Game theory applications in production researc...
# 4  Drug recall management and channel coordinatio...
# 5  Social sustainable supplier evaluation and sel...
#
#                                         affiliations
# 0  [[[<a class="author" href="/author/Aghashahi%2...
# 1  [[[<a class="author" href="/author/Fakhar%2C+A...
# 2  [[[<a class="author" href="/author/Song%2C+Kai...
# 3  [[[<a class="author" href="/author/Choi%2C+Tsa...
# 4  [[[<a class="author" href="/author/Hosseini-Mo...
# 5  [[[<a class="author" href="/author/Bai%2C+Chun...
