# %%
from bs4 import BeautifulSoup
import requests
import pandas
titlesArray=[]
keywordsArray=[]
affilisArray=[]
abstractsArray=[]
publicationsArray=[]
linksArray=[]
publisherArray=[]


tags = requests.get('https://scholar.google.com/scholar?start=0&q=blockchain+iran+springer+-BOOK&hl=en&as_sdt=0,5&as_ylo=2018&as_vis=1').text
soup = BeautifulSoup(tags, 'html') 


                            
linksOfTitles=soup.select('#gs_res_ccl_mid > div > div.gs_ri > h3>a')
for link in linksOfTitles:
  linksArray.append(link['href'])
        
data={ 'links':linksArray}
d= pandas.DataFrame(data)
d[d.links.str.contains('link.springer.com')]
# print(d[d.links.str.contains('link.springer.com')])

for ind in d[d.links.str.contains('link.springer.com')].index:
    link2=d[d.links.str.contains('link.springer.com')]['links'][ind]
    print(link2)
    tags2 = requests.get(link2)
    soup2 = BeautifulSoup(tags2.text, 'html')
    
    
    publisherArray.append('springer')

    
    abstracts=soup2.select('#Abs1-content > p')
    for abstract in abstracts:
     abstractsArray.append(abstract.text)

               
    titles=soup2.select('#main-content > main > article > div.c-article-header > header > h1')
    for title in titles:
     titlesArray.append(title.text)
    

    affiliations=soup2.select('#author-information-content > ol')
    for affili in affiliations:
     affilisArray.append(affili)
    
    

        
       
data={'publisher':publisherArray, 'abstracts':abstractsArray, 'titles':titlesArray,'affiliations':affilisArray, }
df= pandas.DataFrame(data)
print(df)
df.to_excel("C:/Users/musta/Desktop/scholar_scrape/excel/springer0.xlsx")
# Out:
# https://link.springer.com/article/10.1007/s11356-021-18311-7
# https://link.springer.com/article/10.1007/s42044-019-00044-z
# https://link.springer.com/article/10.1007/s11356-022-20334-7
# https://link.springer.com/article/10.1007/s11042-022-12617-5
# https://link.springer.com/article/10.1007/s12652-021-03672-1
# https://link.springer.com/article/10.1007/s11356-021-15552-4
# https://link.springer.com/article/10.1007/s12652-020-01710-y
# https://link.springer.com/article/10.1007/s10479-021-04396-3
#   publisher                                          abstracts  \
# 0  springer  With the advent of new technologies and global...
# 1  springer  The blockchain is nothing but a skilled magici...
# 2  springer  Blockchain Technology (BCT) is expanding day b...
# 3  springer  Security is an important issue in current and ...
# 4  springer  There is an increasing demand for the security...
# 5  springer  One of the significant challenges in urbanizat...
# 6  springer  The development of Electronic Information Tech...
# 7  springer  Supply chains (SCs) are susceptible to risks b...
#
#                                               titles  \
# 0  Blockchain Technology Application Challenges i...
# 1  Blockchain-based security management of IoT in...
# 2  Resource-constrained time–cost-quality-energy-...
# 3  Blockchain based security framework for sharin...
# 4  A conditional privacy-preserving fair electron...
# 5  A novel viewpoint to the green city concept ba...
# 6  MedSBA: a novel and secure scheme to share med...
# 7  Risks to Big Data Analytics and Blockchain Tec...
#
#                                         affiliations
# 0  [[[Applied College, Mechanical Engineering Tec...
# 1  [[[Department of Information and Communication...
# 2  [[[Department of Industrial Engineering, Yazd ...
# 3  [[[Department of Computer Science and Engineer...
# 4  [[[Department of Electrical and Computer Engin...
# 5  [[[Department of Civil Engineering, Sharif Uni...
# 6  [[[Department of Computer Engineering, Univers...
# 7  [[[Department of Mechanical Engineering, K. J....
